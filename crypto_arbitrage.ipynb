# %% [markdown]
# ## Crypto Arbitrage
#
# In this Challenge, you'll take on the role of an analyst at a high-tech investment firm. The vice president (VP) of your department is considering arbitrage opportunities in Bitcoin and other cryptocurrencies. As Bitcoin trades on markets across the globe, can you capitalize on simultaneous price dislocations in those markets by using the powers of Pandas?
#
# For this assignment, you’ll sort through historical trade data for Bitcoin on two exchanges: Bitstamp and Coinbase. Your task is to apply the three phases of financial analysis to determine if any arbitrage opportunities exist for Bitcoin.
#
# This aspect of the Challenge will consist of 3 phases.
#
# 1. Collect the data.
#
# 2. Prepare the data.
#
# 3. Analyze the data.

# %% [markdown]
# ###  Import the required libraries and dependencies.

# %%
import pandas as pd
from pathlib import Path
# %matplotlib inline

# %% [markdown]
# ## Collect the Data
#
# To collect the data that you’ll need, complete the following steps:
#
# Instructions.
#
# 1. Using the Pandas `read_csv` function and the `Path` module, import the data from `bitstamp.csv` file, and create a DataFrame called `bitstamp`. Set the DatetimeIndex as the Timestamp column, and be sure to parse and format the dates.
#
# 2. Use the `head` (and/or the `tail`) function to confirm that Pandas properly imported the data.
#
# 3. Repeat Steps 1 and 2 for `coinbase.csv` file.

# %% [markdown]
# ### Step 1: Using the Pandas `read_csv` function and the `Path` module, import the data from `bitstamp.csv` file, and create a DataFrame called `bitstamp`. Set the DatetimeIndex as the Timestamp column, and be sure to parse and format the dates.

# %%
# Read in the CSV file called "bitstamp.csv" using the Path module. 
# The CSV file is located in the Resources folder.
# Set the index to the column "Timestamp"
# Set the parse_dates and infer_datetime_format parameters
bitstamp = pd.read_csv(
    Path("./Resources/bitstamp.csv"), 
    index_col='Timestamp', 
    infer_datetime_format=True, 
    parse_dates=True
)
#Using pandas I created a read_csv function and named the data frame bitstamp.  I also correct the instructions above that said set index to Date instead of Timestamp.

# %% [markdown]
# ### Step 2: Use the `head` (and/or the `tail`) function to confirm that Pandas properly imported the data.

# %%
# Use the head (and/or tail) function to confirm that the data was imported properly.
bitstamp.head()
#Using the head function we called the first 5 rows of the Data frame labeled bitstamp.
# Out:
#                          Open      High       Low      Close  BTC Volume  \
# Timestamp
# 2018-01-01 00:00:00  13681.04  13681.04  13637.93  $13646.48    3.334553
# 2018-01-01 00:01:00  13646.48  13658.75  13610.18  $13658.75    2.663188
# 2018-01-01 00:02:00  13616.93  13616.93  13610.06  $13610.22    0.084653
# 2018-01-01 00:03:00  13610.27  13639.09  13610.27  $13639.09    7.182986
# 2018-01-01 00:04:00  13635.35  13636.35  13620.00   $13620.0    1.069665
#
#                        USD Volume  Weighted Price
# Timestamp
# 2018-01-01 00:00:00  45482.128785    13639.647479
# 2018-01-01 00:01:00  36361.390888    13653.332816
# 2018-01-01 00:02:00   1152.144036    13610.136247
# 2018-01-01 00:03:00  97856.416478    13623.361128
# 2018-01-01 00:04:00  14582.660932    13632.923329

# %% [markdown]
# ### Step 3: Repeat Steps 1 and 2 for `coinbase.csv` file.

# %%
# Read in the CSV file called "coinbase.csv" using the Path module. 
# The CSV file is located in the Resources folder.
# Set the index to the column "Timestamp"
# Set the parse_dates and infer_datetime_format parameters
coinbase = pd.read_csv(
    Path("./Resources/coinbase.csv"), 
    index_col='Timestamp', 
    infer_datetime_format=True, 
    parse_dates=True
)
#Like earlier we created a read_csv function and named the data frame coinbase.

# %%
# Use the head (and/or tail) function to confirm that the data was imported properly.
coinbase.head()
#Using the head function we called the first 5 rows of the Data frame labeled coinbase.
# Out:
#                          Open      High       Low      Close  BTC Volume  \
# Timestamp
# 2018-01-01 00:00:00  13620.00  13620.00  13608.49  $13608.49   20.812754
# 2018-01-01 00:01:00  13607.14  13607.14  13601.66  $13601.66   13.474359
# 2018-01-01 00:02:00  13601.44  13601.44  13580.00   $13580.0   11.536360
# 2018-01-01 00:03:00  13587.31  13587.31  13542.70  $13550.34   16.328039
# 2018-01-01 00:04:00  13550.34  13585.95  13550.34  $13583.44    9.955364
#
#                        USD Volume  Weighted Price
# Timestamp
# 2018-01-01 00:00:00  283451.08537    13619.105106
# 2018-01-01 00:01:00  183283.97801    13602.426919
# 2018-01-01 00:02:00  156789.19686    13590.872506
# 2018-01-01 00:03:00  221413.64182    13560.332806
# 2018-01-01 00:04:00  135141.26944    13574.719401

# %% [markdown]
# ## Prepare the Data
#
# To prepare and clean your data for analysis, complete the following steps:
#
# 1. For the bitstamp DataFrame, replace or drop all `NaN`, or missing, values in the DataFrame.
#
# 2. Use the `str.replace` function to remove the dollar signs ($) from the values in the Close column.
#
# 3. Convert the data type of the Close column to a `float`.
#
# 4. Review the data for duplicated values, and drop them if necessary.
#
# 5. Repeat Steps 1–4 for the coinbase DataFrame.

# %% [markdown]
# ### Step 1: For the bitstamp DataFrame, replace or drop all `NaN`, or missing, values in the DataFrame.

# %%
# For the bitstamp DataFrame, replace or drop all NaNs or missing values in the DataFrame
bitstamp.dropna()
#Using dropna.() we eliminated all the NaN or missing values in the data frame bitstamp.
# Out:
#                          Open      High       Low      Close  BTC Volume  \
# Timestamp
# 2018-01-01 00:00:00  13681.04  13681.04  13637.93  $13646.48    3.334553
# 2018-01-01 00:01:00  13646.48  13658.75  13610.18  $13658.75    2.663188
# 2018-01-01 00:02:00  13616.93  13616.93  13610.06  $13610.22    0.084653
# 2018-01-01 00:03:00  13610.27  13639.09  13610.27  $13639.09    7.182986
# 2018-01-01 00:04:00  13635.35  13636.35  13620.00   $13620.0    1.069665
# ...                       ...       ...       ...        ...         ...
# 2018-03-31 23:55:00   6935.01   6939.07   6922.56   $6922.56    1.044354
# 2018-03-31 23:56:00   6922.02   6922.02   6918.00   $6920.32    3.069539
# 2018-03-31 23:57:00   6920.33   6936.42   6920.33   $6934.72   28.239049
# 2018-03-31 23:58:00   6927.65   6929.42   6927.65   $6927.65    0.839507
# 2018-03-31 23:59:00   6929.98   6929.98   6928.00   $6928.01    0.209363
#
#                         USD Volume  Weighted Price
# Timestamp
# ...

# %% [markdown]
# ### Step 2: Use the `str.replace` function to remove the dollar signs ($) from the values in the Close column.

# %%
# Use the str.replace function to remove the dollar sign, $
bitstamp.loc[:, "Close"] = bitstamp.loc[:, "Close"].str.replace("$", "")
bitstamp.head()
#Using loc and str.replace I was able to remove the "$" sign from the close column.  I ran the head of the data frame to ensure the "$" was no longer in the data frame.
# Out:
# /var/folders/7v/fw5l_m4d4ql602nzxfwxv9dc0000gn/T/ipykernel_9943/4262604335.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   bitstamp.loc[:, "Close"] = bitstamp.loc[:, "Close"].str.replace("$", "")
#                          Open      High       Low     Close  BTC Volume  \
# Timestamp
# 2018-01-01 00:00:00  13681.04  13681.04  13637.93  13646.48    3.334553
# 2018-01-01 00:01:00  13646.48  13658.75  13610.18  13658.75    2.663188
# 2018-01-01 00:02:00  13616.93  13616.93  13610.06  13610.22    0.084653
# 2018-01-01 00:03:00  13610.27  13639.09  13610.27  13639.09    7.182986
# 2018-01-01 00:04:00  13635.35  13636.35  13620.00   13620.0    1.069665
#
#                        USD Volume  Weighted Price
# Timestamp
# 2018-01-01 00:00:00  45482.128785    13639.647479
# 2018-01-01 00:01:00  36361.390888    13653.332816
# ...

# %% [markdown]
# ### Step 3: Convert the data type of the Close column to a `float`.

# %%
# Convert the Close data type to a float
bitstamp.loc[:, "Close"] = bitstamp.loc[:, "Close"].astype("float")
bitstamp.dtypes
#Using loc I was able to identify the "Close" column and change the data type to float.  I ran dtypes on the data frame to ensure the changes took place.
# Out:
# Open              float64
# High              float64
# Low               float64
# Close             float64
# BTC Volume        float64
# USD Volume        float64
# Weighted Price    float64
# dtype: object

# %% [markdown]
# ### Step 4: Review the data for duplicated values, and drop them if necessary.

# %%
# Review the data for duplicate values, and drop them if necessary
bitstamp.duplicated().sum()
#Using duplicated and sum I was able to detemine the number of duplicates in the file is 427.
# Out:
# 472

# %%
#Using drop duplicates I was able to remove the duplicates from the file.
bitstamp = bitstamp.drop_duplicates()
bitstamp.duplicated().sum()
#You can see after completing the drop_duplicates when we run duplicated and sum again the total is zero.
# Out:
# 0

# %% [markdown]
# ### Step 5: Repeat Steps 1–4 for the coinbase DataFrame.

# %%
# Repeat Steps 1–4 for the coinbase DataFrame
coinbase.dropna()
#Using dropna.() we eliminated all the NaN or missing values in the data frame coinbase.
# Out:
#                          Open      High       Low      Close  BTC Volume  \
# Timestamp
# 2018-01-01 00:00:00  13620.00  13620.00  13608.49  $13608.49   20.812754
# 2018-01-01 00:01:00  13607.14  13607.14  13601.66  $13601.66   13.474359
# 2018-01-01 00:02:00  13601.44  13601.44  13580.00   $13580.0   11.536360
# 2018-01-01 00:03:00  13587.31  13587.31  13542.70  $13550.34   16.328039
# 2018-01-01 00:04:00  13550.34  13585.95  13550.34  $13583.44    9.955364
# ...                       ...       ...       ...        ...         ...
# 2018-03-31 23:55:00   6945.20   6948.06   6930.00    $6930.0    5.802288
# 2018-03-31 23:56:00   6930.00   6930.01   6930.00   $6930.01    0.625053
# 2018-03-31 23:57:00   6930.01   6933.91   6930.01   $6933.91    0.776431
# 2018-03-31 23:58:00   6933.91   6938.00   6933.90   $6937.31    0.133413
# 2018-03-31 23:59:00   6937.30   6937.30   6931.09    $6934.0    1.012720
#
#                         USD Volume  Weighted Price
# Timestamp
# ...

# %%
coinbase.loc[:, "Close"] = coinbase.loc[:, "Close"].str.replace("$", "")
coinbase.head()
#Using loc and str.replace I was able to remove the "$" sign from the close column.  I ran the head of the data frame to ensure the "$" was no longer in the data frame.
# Out:
# /var/folders/7v/fw5l_m4d4ql602nzxfwxv9dc0000gn/T/ipykernel_9943/1196638168.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   coinbase.loc[:, "Close"] = coinbase.loc[:, "Close"].str.replace("$", "")
#                          Open      High       Low     Close  BTC Volume  \
# Timestamp
# 2018-01-01 00:00:00  13620.00  13620.00  13608.49  13608.49   20.812754
# 2018-01-01 00:01:00  13607.14  13607.14  13601.66  13601.66   13.474359
# 2018-01-01 00:02:00  13601.44  13601.44  13580.00   13580.0   11.536360
# 2018-01-01 00:03:00  13587.31  13587.31  13542.70  13550.34   16.328039
# 2018-01-01 00:04:00  13550.34  13585.95  13550.34  13583.44    9.955364
#
#                        USD Volume  Weighted Price
# Timestamp
# 2018-01-01 00:00:00  283451.08537    13619.105106
# 2018-01-01 00:01:00  183283.97801    13602.426919
# ...

# %%
# Convert the Close data type to a float
coinbase.loc[:, "Close"] = coinbase.loc[:, "Close"].astype("float")
coinbase.dtypes
#Using loc I was able to identify the "Close" column and change the data type to float.  I ran dtypes on the data frame to ensure the changes took place.
# Out:
# Open              float64
# High              float64
# Low               float64
# Close             float64
# BTC Volume        float64
# USD Volume        float64
# Weighted Price    float64
# dtype: object

# %%
coinbase.duplicated().sum()
#Using duplicated and sum I was able to detemine the number of duplicates in the file is 217.
# Out:
# 217

# %%
coinbase = coinbase.drop_duplicates()
coinbase.duplicated().sum()
#You can see after completing the drop_duplicates when we run duplicated and sum again the total is zero.
# Out:
# 0

# %% [markdown]
# ## Analyze the Data
#
# Your analysis consists of the following tasks:
#
# 1. Choose the columns of data on which to focus your analysis.
#
# 2. Get the summary statistics and plot the data.
#
# 3. Focus your analysis on specific dates.
#
# 4. Calculate the arbitrage profits.

# %% [markdown]
# ### Step 1: Choose columns of data on which to focus your analysis.
#
# Select the data you want to analyze. Use `loc` or `iloc` to select the following columns of data for both the bitstamp and coinbase DataFrames:
#
# * Timestamp (index)
#
# * Close

# %%
# Use loc or iloc to select `Timestamp (the index)` and `Close` from bitstamp DataFrame
bitstamp_sliced = bitstamp.loc[:,"Close"]

# Review the first five rows of the DataFrame
bitstamp_sliced.head()
#Using loc I was able to pull only the column "Close" from the bitstamp data frame.
# Out:
# Timestamp
# 2018-01-01 00:00:00    13646.48
# 2018-01-01 00:01:00    13658.75
# 2018-01-01 00:02:00    13610.22
# 2018-01-01 00:03:00    13639.09
# 2018-01-01 00:04:00    13620.00
# Name: Close, dtype: float64

# %%
# Use loc or iloc to select `Timestamp (the index)` and `Close` from coinbase DataFrame
coinbase_sliced = coinbase.loc[:, "Close"]

# Review the first five rows of the DataFrame
coinbase_sliced.head()
#Using loc I was able to pull only the column "Close" from the coinbase data frame.
# Out:
# Timestamp
# 2018-01-01 00:00:00    13608.49
# 2018-01-01 00:01:00    13601.66
# 2018-01-01 00:02:00    13580.00
# 2018-01-01 00:03:00    13550.34
# 2018-01-01 00:04:00    13583.44
# Name: Close, dtype: float64

# %% [markdown]
# ### Step 2: Get summary statistics and plot the data.
#
# Sort through the time series data associated with the bitstamp and coinbase DataFrames to identify potential arbitrage opportunities. To do so, complete the following steps:
#
# 1. Generate the summary statistics for each DataFrame by using the `describe` function.
#
# 2. For each DataFrame, create a line plot for the full period of time in the dataset. Be sure to tailor the figure size, title, and color to each visualization.
#
# 3. In one plot, overlay the visualizations that you created in Step 2 for bitstamp and coinbase. Be sure to adjust the legend and title for this new visualization.
#
# 4. Using the `loc` and `plot` functions, plot the price action of the assets on each exchange for different dates and times. Your goal is to evaluate how the spread between the two exchanges changed across the time period that the datasets define. Did the degree of spread change as time progressed?

# %%
# Generate the summary statistics for the bitstamp DataFrame
bitstamp_sliced.describe()
#The summary statistics are retrieved for the data frame when the describe function is used.
# Out:
# count    129067.000000
# mean      10459.842453
# std        2315.976088
# min        5944.000000
# 25%        8613.370000
# 50%       10145.950000
# 75%       11444.810000
# max       17234.980000
# Name: Close, dtype: float64

# %%
# Generate the summary statistics for the coinbase DataFrame
coinbase_sliced.describe()
#The summary statistics are retrieved for the data frame when the describe function is used.
# Out:
# count    129322.000000
# mean      10449.140958
# std        2317.197419
# min        5882.310000
# 25%        8609.230000
# 50%       10137.440000
# 75%       11397.237500
# max       17177.990000
# Name: Close, dtype: float64

# %%
# Create a line plot for the bitstamp DataFrame for the full length of time in the dataset 
# Be sure that the figure size, title, and color are tailored to each visualization
bitstamp["Close"].plot(legend=True, figsize=(15,10), title="Bitstamp Prices", color="blue")

#Created a line plot for Bitstamp data frame.
# Out:
# <AxesSubplot:title={'center':'Bitstamp Prices'}, xlabel='Timestamp'>

# %%
# Create a line plot for the coinbase DataFrame for the full length of time in the dataset 
# Be sure that the figure size, title, and color are tailored to each visualization
coinbase["Close"].plot(legend=True, figsize=(15,10), title="Coinbase Prices", color="red")
#Created a line plot for Coinbase data frame.
# Out:
# <AxesSubplot:title={'center':'Coinbase Prices'}, xlabel='Timestamp'>

# %%
# Overlay the visualizations for the bitstamp and coinbase DataFrames in one plot
# The plot should visualize the prices over the full lenth of the dataset
# Be sure to include the parameters: legend, figure size, title, and color and label
bitstamp['Close'].plot(legend=True, figsize=(15, 10), title="Bitstamp v Coinbase", color="blue", label="Bitstamp")
coinbase['Close'].plot(legend=True, figsize=(15, 10), color="red", label="Coinbase")
#Below is an overlay of Bitstamp and Coinbase Close prices.
# Out:
# <AxesSubplot:title={'center':'Bitstamp v Coinbase'}, xlabel='Timestamp'>

# %%
# Using the loc and plot functions, create an overlay plot that visualizes 
# the price action of both DataFrames for a one month period early in the dataset
# Be sure to include the parameters: legend, figure size, title, and color and label
bitstamp['Close'].loc['2018-01-01': '2018-01-31'].plot(
    legend=True, figsize=(15, 10), title="Bitstamp v Coinbase January 2018", color="blue", label="Bitstamp")
coinbase['Close'].loc['2018-01-01': '2018-01-31'].plot(
    legend=True, figsize=(15, 10), color="red", label="Coinbase")
#Using the code above I was able to overlay Bitstamp and Coinbase for January 2018.
# Out:
# <AxesSubplot:title={'center':'Bitstamp v Coinbase January 2018'}, xlabel='Timestamp'>

# %%
# Using the loc and plot functions, create an overlay plot that visualizes 
# the price action of both DataFrames for a one month period later in the dataset
# Be sure to include the parameters: legend, figure size, title, and color and label 
bitstamp['Close'].loc['2018-03-01': '2018-03-31'].plot(
    legend=True, figsize=(15, 10), title="Bitstamp v Coinbase March 2018", color="blue", label="Bitstamp")
coinbase['Close'].loc['2018-03-01': '2018-03-31'].plot(
    legend=True, figsize=(15, 10), color="red", label="Coinbase")
#Using the code above I was able to overlay Bitstamp and Coinbase for March 2018.
# Out:
# <AxesSubplot:title={'center':'Bitstamp v Coinbase March 2018'}, xlabel='Timestamp'>

# %% [markdown]
# **Question** Based on the visualizations of the different time periods, has the degree of spread change as time progressed?
#
# **Answer** Yes it has, in the month of January you see quite a few defferences especially around the 29th of January.  March has less noticable differences witht he line plots being very closely related to each other.

# %% [markdown]
# ### Step 3: Focus Your Analysis on Specific Dates
#
# Focus your analysis on specific dates by completing the following steps:
#
# 1. Select three dates to evaluate for arbitrage profitability. Choose one date that’s early in the dataset, one from the middle of the dataset, and one from the later part of the time period.
#
# 2. For each of the three dates, generate the summary statistics and then create a box plot. This big-picture view is meant to help you gain a better understanding of the data before you perform your arbitrage calculations. As you compare the data, what conclusions can you draw?

# %%
# Create an overlay plot that visualizes the two dataframes over a period of one day early in the dataset. 
# Be sure that the plots include the parameters `legend`, `figsize`, `title`, `color` and `label` 
bitstamp['Close'].loc['2018-01-29'].plot(
    legend=True, figsize=(15, 10), title="Bitstamp v Coinbase January 29th, 2018", color="blue", label="Bitstamp")
coinbase['Close'].loc['2018-01-29'].plot(
    legend=True, figsize=(15, 10), color="red", label="Coinbase")
#Using the code above I did a line plot of January 29th, 2018 for Bitstamp and Coinbase.
# Out:
# <AxesSubplot:title={'center':'Bitstamp v Coinbase January 29th, 2018'}, xlabel='Timestamp'>

# %%
# Using the early date that you have selected, calculate the arbitrage spread 
# by subtracting the bitstamp lower closing prices from the coinbase higher closing prices
arbitrage_spread_early = bitstamp['Close'].loc['2018-01-29'] - coinbase['Close'].loc['2018-01-29']

# Generate summary statistics for the early DataFrame
arbitrage_spread_early.describe()
#I was able to run statistics for the arbitrage spread for January 29th, 2018 after comparing closes between Bitstamp and Coinbase.
# Out:
# count    1430.000000
# mean      120.214510
# std        85.164846
# min       -48.010000
# 25%        37.002500
# 50%       132.420000
# 75%       203.237500
# max       300.270000
# Name: Close, dtype: float64

# %%
# Visualize the arbitrage spread from early in the dataset in a box plot
arbitrage_spread_early.plot(kind="box", figsize= (10,5), title="January 29th, 2018 spread")
#Box plot using the arbitrage_spread_early data frame.
# Out:
# <AxesSubplot:title={'center':'January 29th, 2018 spread'}>

# %%
# Create an overlay plot that visualizes the two dataframes over a period of one day from the middle of the dataset. 
# Be sure that the plots include the parameters `legend`, `figsize`, `title`, `color` and `label` 
bitstamp['Close'].loc['2018-02-02'].plot(
    legend=True, figsize=(15, 10), title="Bitstamp v Coinbase Groundhog Day 2018", color="blue", label="Bitstamp")
coinbase['Close'].loc['2018-02-02'].plot(
    legend=True, figsize=(15, 10), color="red", label="Coinbase")
#Using the code above I did a line plot of Groundhog Day 2018 for Bitstamp and Coinbase.
# Out:
# <AxesSubplot:title={'center':'Bitstamp v Coinbase Groundhog Day 2018'}, xlabel='Timestamp'>

# %%
# Using the date in the middle that you have selected, calculate the arbitrage spread 
# by subtracting the bitstamp lower closing prices from the coinbase higher closing prices
arbitrage_spread_middle = bitstamp['Close'].loc['2018-02-02'] - coinbase['Close'].loc['2018-02-02']

# Generate summary statistics 
arbitrage_spread_middle.describe()
#I was able to run statistics for the arbitrage spread for February 2nd,(Groundhog Day) 2018  after comparing closes between Bitstamp and Coinbase.
# Out:
# count    1440.000000
# mean       17.735333
# std        29.471733
# min      -188.550000
# 25%         2.362500
# 50%        19.995000
# 75%        34.587500
# max       140.010000
# Name: Close, dtype: float64

# %%
# Visualize the arbitrage spread from the middle of the dataset in a box plot
arbitrage_spread_middle.plot(kind="box",figsize= (10,5), title="February 2nd, 2018 spread")
#Box plot using the arbitrage_spread_middle data frame.
# Out:
# <AxesSubplot:title={'center':'February 2nd, 2018 spread'}>

# %%
# Create an overlay plot that visualizes the two dataframes over a period of one day from late in the dataset. 
# Be sure that the plots include the parameters `legend`, `figsize`, `title`, `color` and `label` 
bitstamp['Close'].loc['2018-03-02'].plot(
    legend=True, figsize=(15, 10), title="Bitstamp v Coinbase March 2nd, 2018", color="blue", label="Bitstamp")
coinbase['Close'].loc['2018-03-02'].plot(
    legend=True, figsize=(15, 10), color="red", label="Coinbase")
#Using the code above I did a line plot of March 2nd, 2018 for Bitstamp and Coinbase.
# Out:
# <AxesSubplot:title={'center':'Bitstamp v Coinbase March 2nd, 2018'}, xlabel='Timestamp'>

# %%
# Using the date from the late that you have selected, calculate the arbitrage spread 
# by subtracting the bitstamp lower closing prices from the coinbase higher closing prices
arbitrage_spread_late = bitstamp['Close'].loc['2018-03-02'] - coinbase['Close'].loc['2018-03-02']

# Generate summary statistics for the late DataFrame
arbitrage_spread_late.describe()
#I was able to run statistics for the arbitrage spread for March 2nd, 2018  after comparing closes between Bitstamp and Coinbase.
# Out:
# count    1435.000000
# mean       10.598418
# std        14.068265
# min       -32.460000
# 25%         0.770000
# 50%        10.150000
# 75%        20.080000
# max        81.100000
# Name: Close, dtype: float64

# %%
# Visualize the arbitrage spread from late in the dataset in a box plot
arbitrage_spread_late.plot(kind="box", figsize= (10,5), title="March 2nd, 2018 spread")
#Box plot using the arbitrage_spread_late data frame.
# Out:
# <AxesSubplot:title={'center':'March 2nd, 2018 spread'}>

# %% [markdown]
# ### Step 4: Calculate the Arbitrage Profits
#
# Calculate the potential profits for each date that you selected in the previous section. Your goal is to determine whether arbitrage opportunities still exist in the Bitcoin market. Complete the following steps:
#
# 1. For each of the three dates, measure the arbitrage spread between the two exchanges by subtracting the lower-priced exchange from the higher-priced one. Then use a conditional statement to generate the summary statistics for each arbitrage_spread DataFrame, where the spread is greater than zero.
#
# 2. For each of the three dates, calculate the spread returns. To do so, divide the instances that have a positive arbitrage spread (that is, a spread greater than zero) by the price of Bitcoin from the exchange you’re buying on (that is, the lower-priced exchange). Review the resulting DataFrame.
#
# 3. For each of the three dates, narrow down your trading opportunities even further. To do so, determine the number of times your trades with positive returns exceed the 1% minimum threshold that you need to cover your costs.
#
# 4. Generate the summary statistics of your spread returns that are greater than 1%. How do the average returns compare among the three dates?
#
# 5. For each of the three dates, calculate the potential profit, in dollars, per trade. To do so, multiply the spread returns that were greater than 1% by the cost of what was purchased. Make sure to drop any missing values from the resulting DataFrame.
#
# 6. Generate the summary statistics, and plot the results for each of the three DataFrames.
#
# 7. Calculate the potential arbitrage profits that you can make on each day. To do so, sum the elements in the profit_per_trade DataFrame.
#
# 8. Using the `cumsum` function, plot the cumulative sum of each of the three DataFrames. Can you identify any patterns or trends in the profits across the three time periods?
#
# (NOTE: The starter code displays only one date. You'll want to do this analysis for two additional dates).

# %% [markdown]
# #### 1. For each of the three dates, measure the arbitrage spread between the two exchanges by subtracting the lower-priced exchange from the higher-priced one. Then use a conditional statement to generate the summary statistics for each arbitrage_spread DataFrame, where the spread is greater than zero.
#
# *NOTE*: For illustration, only one of the three dates is shown in the starter code below.

# %%
# For the date early in the dataset, measure the arbitrage spread between the two exchanges
# by subtracting the lower-priced exchange from the higher-priced one
arbitrage_spread_early = bitstamp['Close'].loc['2018-01-29'] - coinbase['Close'].loc['2018-01-29']

# Use a conditional statement to generate the summary statistics for each arbitrage_spread DataFrame
spread_return_early = arbitrage_spread_early[arbitrage_spread_early > 0]
spread_return_early.describe()
#Using the arbitrage_spread_early we created a data frame that contains transactions for arbitrage greater than zero.
# Out:
# count    1379.000000
# mean      124.976425
# std        82.959829
# min         0.570000
# 25%        41.885000
# 50%       144.380000
# 75%       204.135000
# max       300.270000
# Name: Close, dtype: float64

# %%
# For the date early in the dataset, measure the arbitrage spread between the two exchanges
# by subtracting the lower-priced exchange from the higher-priced one
arbitrage_spread_middle = bitstamp['Close'].loc['2018-02-02'] - coinbase['Close'].loc['2018-02-02']

# Use a conditional statement to generate the summary statistics for each arbitrage_spread DataFrame
spread_return_middle = arbitrage_spread_middle[arbitrage_spread_middle > 0]
spread_return_middle.describe()
#Using the arbitrage_spread_middle we created a data frame that contains transactions for arbitrage greater than zero.
# Out:
# count    1114.000000
# mean       29.146724
# std        20.123466
# min         0.010000
# 25%        15.732500
# 50%        26.460000
# 75%        39.120000
# max       140.010000
# Name: Close, dtype: float64

# %%
# For the date early in the dataset, measure the arbitrage spread between the two exchanges
# by subtracting the lower-priced exchange from the higher-priced one
arbitrage_spread_late = bitstamp['Close'].loc['2018-03-02'] - coinbase['Close'].loc['2018-03-02']

# Use a conditional statement to generate the summary statistics for each arbitrage_spread DataFrame
spread_return_late = arbitrage_spread_late[arbitrage_spread_late > 0]
spread_return_late.describe()
#Using the arbitrage_spread_late we created a data frame that contains transactions for arbitrage greater than zero.
# Out:
# count    1104.000000
# mean       15.967446
# std        11.052859
# min         0.010000
# 25%         7.200000
# 50%        14.180000
# 75%        23.425000
# max        81.100000
# Name: Close, dtype: float64

# %% [markdown]
# #### 2. For each of the three dates, calculate the spread returns. To do so, divide the instances that have a positive arbitrage spread (that is, a spread greater than zero) by the price of Bitcoin from the exchange you’re buying on (that is, the lower-priced exchange). Review the resulting DataFrame.

# %%
# For the date early in the dataset, calculate the spread returns by dividing the instances when the arbitrage spread is positive (> 0) 
# by the price of Bitcoin from the exchange you are buying on (the lower-priced exchange).
spread_return_early= spread_return_early = arbitrage_spread_early[arbitrage_spread_early > 0] / coinbase['Close'].loc['2018-01-29']

# Review the spread return DataFrame
spread_return_early.head()
#Dividing the lines above zero by the lower of the two exchanges.
# Out:
# Timestamp
# 2018-01-29 00:00:00    0.017925
# 2018-01-29 00:01:00    0.019284
# 2018-01-29 00:02:00    0.019307
# 2018-01-29 00:03:00    0.019840
# 2018-01-29 00:04:00    0.018541
# Name: Close, dtype: float64

# %%
spread_return_middle= spread_return_middle = arbitrage_spread_middle[arbitrage_spread_middle > 0] / coinbase['Close'].loc['2018-02-02']
spread_return_middle.head()
#Dividing the lines above zero by the lower of the two exchanges.
# Out:
# Timestamp
# 2018-02-02 00:00:00        NaN
# 2018-02-02 00:01:00        NaN
# 2018-02-02 00:02:00        NaN
# 2018-02-02 00:03:00        NaN
# 2018-02-02 00:04:00    0.00018
# Name: Close, dtype: float64

# %%
spread_return_late= spread_return_late = arbitrage_spread_late[arbitrage_spread_late > 0] / coinbase['Close'].loc['2018-03-02']
spread_return_late.head()
#Dividing the lines above zero by the lower of the two exchanges.
# Out:
# Timestamp
# 2018-03-02 00:00:00    0.001086
# 2018-03-02 00:01:00    0.000249
# 2018-03-02 00:02:00         NaN
# 2018-03-02 00:03:00    0.000003
# 2018-03-02 00:04:00         NaN
# Name: Close, dtype: float64

# %% [markdown]
# #### 3. For each of the three dates, narrow down your trading opportunities even further. To do so, determine the number of times your trades with positive returns exceed the 1% minimum threshold that you need to cover your costs.

# %%
# For the date early in the dataset, determine the number of times your trades with positive returns 
# exceed the 1% minimum threshold (.01) that you need to cover your costs
profitable_trades_early = spread_return_early[spread_return_early > .01]

# Review the first five profitable trades
profitable_trades_early.head()
#Created another data set for returns greater than .01 to cover fees related to trading.
# Out:
# Timestamp
# 2018-01-29 00:00:00    0.017925
# 2018-01-29 00:01:00    0.019284
# 2018-01-29 00:02:00    0.019307
# 2018-01-29 00:03:00    0.019840
# 2018-01-29 00:04:00    0.018541
# Name: Close, dtype: float64

# %%
profitable_trades_middle = spread_return_middle[spread_return_middle > .01]

# Review the first five profitable trades
profitable_trades_middle.head()
#Created another data set for returns greater than .01 to cover fees related to trading.
# Out:
# Timestamp
# 2018-02-02 06:50:00    0.012374
# 2018-02-02 07:17:00    0.010137
# 2018-02-02 07:27:00    0.012033
# 2018-02-02 07:28:00    0.011289
# 2018-02-02 07:29:00    0.011974
# Name: Close, dtype: float64

# %%
profitable_trades_late = spread_return_late[spread_return_late > .01]

# Review the first five profitable trades
profitable_trades_late.head()
#Created another data set for returns greater than .01 to cover fees related to trading.
# Out:
# Series([], Name: Close, dtype: float64)

# %% [markdown]
# #### 4. Generate the summary statistics of your spread returns that are greater than 1%. How do the average returns compare among the three dates?

# %%
# For the date early in the dataset, generate the summary statistics for the profitable trades
# or you trades where the spread returns are are greater than 1%
profitable_trades_early.describe()
#Using describe to generate summary statistics for profitable trades.
# Out:
# count    742.000000
# mean       0.017795
# std        0.003142
# min        0.010021
# 25%        0.015371
# 50%        0.018233
# 75%        0.020063
# max        0.027075
# Name: Close, dtype: float64

# %%
profitable_trades_middle.describe()
#Using describe to generate summary statistics for profitable trades.
# Out:
# count    29.000000
# mean      0.013684
# std       0.002256
# min       0.010040
# 25%       0.012033
# 50%       0.013660
# 75%       0.014564
# max       0.018250
# Name: Close, dtype: float64

# %%
profitable_trades_late.describe()
#Using describe to generate summary statistics for profitable trades.
# Out:
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: Close, dtype: float64

# %% [markdown]
# #### 5. For each of the three dates, calculate the potential profit, in dollars, per trade. To do so, multiply the spread returns that were greater than 1% by the cost of what was purchased. Make sure to drop any missing values from the resulting DataFrame.

# %%
# For the date early in the dataset, calculate the potential profit per trade in dollars 
# Multiply the profitable trades by the cost of the Bitcoin that was purchased
profit_early = profitable_trades_early * bitstamp['Close'].loc['2018-01-29']

# Drop any missing values from the profit DataFrame
profit_per_trade_early = profit_early.dropna()

# View the early profit DataFrame
profit_per_trade_early
#Calculated potential profit and dropped NaN values from the data frame.
# Out:
# Timestamp
# 2018-01-29 00:00:00    205.600508
# 2018-01-29 00:01:00    221.184577
# 2018-01-29 00:02:00    221.413893
# 2018-01-29 00:03:00    227.648779
# 2018-01-29 00:04:00    212.508363
#                           ...
# 2018-01-29 12:24:00    117.763564
# 2018-01-29 12:31:00    129.926193
# 2018-01-29 12:33:00    123.269349
# 2018-01-29 12:37:00    112.536505
# 2018-01-29 12:39:00    113.892830
# Name: Close, Length: 742, dtype: float64

# %%
profit_middle = profitable_trades_middle * bitstamp['Close'].loc['2018-02-02']

# Drop any missing values from the profit DataFrame
profit_per_trade_middle = profit_middle.dropna()

# View the early profit DataFrame
profit_per_trade_middle
#Calculated potential profit and dropped NaN values from the data frame.
# Out:
# Timestamp
# 2018-02-02 06:50:00     98.878594
# 2018-02-02 07:17:00     79.922069
# 2018-02-02 07:27:00     93.977379
# 2018-02-02 07:28:00     88.063008
# 2018-02-02 07:29:00     93.395055
# 2018-02-02 07:30:00    113.347128
# 2018-02-02 07:31:00    102.330160
# 2018-02-02 07:32:00    129.826241
# 2018-02-02 07:33:00    142.565113
# 2018-02-02 07:34:00    134.550416
# 2018-02-02 07:35:00    100.124610
# 2018-02-02 07:36:00    127.049180
# 2018-02-02 07:37:00    119.562844
# 2018-02-02 07:38:00     95.158364
# 2018-02-02 07:39:00     92.054459
# 2018-02-02 07:41:00     95.508341
# 2018-02-02 07:42:00    132.202994
# 2018-02-02 07:43:00    111.625068
# 2018-02-02 07:44:00    130.640781
# 2018-02-02 07:45:00    111.579947
# 2018-02-02 07:46:00     93.652646
# 2018-02-02 07:47:00    107.767787
# 2018-02-02 07:48:00    104.417118
# 2018-02-02 07:49:00    111.223788
# 2018-02-02 14:32:00     86.621073
# 2018-02-02 17:15:00    123.844246
# 2018-02-02 17:16:00    121.668407
# ...

# %%
profit_late = profitable_trades_late * bitstamp['Close'].loc['2018-03-02']

# Drop any missing values from the profit DataFrame
profit_per_trade_late = profit_late.dropna()

# View the early profit DataFrame
profit_per_trade_late
#Calculated potential profit and dropped NaN values from the data frame.
# Out:
# Series([], Name: Close, dtype: float64)

# %% [markdown]
# #### 6. Generate the summary statistics, and plot the results for each of the three DataFrames.

# %%
# Generate the summary statistics for the early profit per trade DataFrame
profit_per_trade_early.describe()
#Summary statistics for profit per trade data frame.
# Out:
# count    742.000000
# mean     200.333292
# std       35.816052
# min      112.323620
# 25%      172.656840
# 50%      204.567757
# 75%      225.427580
# max      308.399667
# Name: Close, dtype: float64

# %%
profit_per_trade_middle.describe()
#Summary statistics for profit per trade data frame.
# Out:
# count     29.000000
# mean     108.128549
# std       16.666064
# min       79.922069
# 25%       93.977379
# 50%      104.417118
# 75%      121.668407
# max      142.565113
# Name: Close, dtype: float64

# %%
profit_per_trade_late.describe()
#Summary statistics for profit per trade data frame.
# Out:
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: Close, dtype: float64

# %%
# Plot the results for the early profit per trade DataFrame
profit_per_trade_early.plot(figsize=(10, 7), title="Profit Per Trade - January 29th, 2018")
#Plotting profit per trade for the day.
# Out:
# <AxesSubplot:title={'center':'Profit Per Trade - January 29th, 2018'}, xlabel='Timestamp'>

# %%
profit_per_trade_middle.plot(figsize=(10, 7), title="Profit Per Trade - February 2nd (Groundhod Day) , 2018")
#Plotting profit per trade for the day.
# Out:
# <AxesSubplot:title={'center':'Profit Per Trade - February 2nd (Groundhod Day) , 2018'}, xlabel='Timestamp'>

# %%
profit_per_trade_late.plot(figsize=(10, 7), title="Profit Per Trade - March 2nd, 2018")
#Plotting profit per trade for the day.
# Out:
# <AxesSubplot:title={'center':'Profit Per Trade - March 2nd, 2018'}, xlabel='Timestamp'>

# %% [markdown]
# #### 7. Calculate the potential arbitrage profits that you can make on each day. To do so, sum the elements in the profit_per_trade DataFrame.

# %%
# Calculate the sum of the potential profits for the early profit per trade DataFrame
profit_sum_early = profit_per_trade_early.sum()
profit_sum_early
#Calculate the sum of potential profits for data frame.
# Out:
# 148647.30257393542

# %%
profit_sum_middle = profit_per_trade_middle.sum()
profit_sum_middle
#Calculate the sum of potential profits for data frame.
# Out:
# 3135.7279255267877

# %%
profit_sum_late = profit_per_trade_late.sum()
profit_sum_late
#Calculate the sum of potential profits for data frame.
# Out:
# 0.0

# %% [markdown]
# #### 8. Using the `cumsum` function, plot the cumulative sum of each of the three DataFrames. Can you identify any patterns or trends in the profits across the three time periods?

# %%
# Use the cumsum function to calculate the cumulative profits over time for the early profit per trade DataFrame
cumulative_profit_early = profit_per_trade_early.cumsum()
#Calculate the cumulative profits over time for the per trade data frame.

# %%
# Plot the cumulative sum of profits for the early profit per trade DataFrame
cumulative_profit_early.plot(figsize=(10, 7), title="Cumulative January 29th, 2018 Profits")
#Plotting the cumulative profits for the data frame.
# Out:
# <AxesSubplot:title={'center':'Cumulative January 29th, 2018 Profits'}, xlabel='Timestamp'>

# %%
cumulative_profit_middle = profit_per_trade_middle.cumsum()
#Calculate the cumulative profits over time for the per trade data frame.

# %%
cumulative_profit_middle.plot(figsize=(10, 7), title="Cumulative February 2nd (Groundhog Day), 2018 Profits")
#Plotting the cumulative profits for the data frame.
# Out:
# <AxesSubplot:title={'center':'Cumulative February 2nd (Groundhog Day), 2018 Profits'}, xlabel='Timestamp'>

# %%
cumulative_profit_late = profit_per_trade_late.cumsum()
#Calculate the cumulative profits over time for the per trade data frame.

# %%
cumulative_profit_late.plot(figsize=(10, 7), title="Cumulative March 2nd, 2018 Profits")
#Plotting the cumulative profits for the data frame.
# Out:
# <AxesSubplot:title={'center':'Cumulative March 2nd, 2018 Profits'}, xlabel='Timestamp'>

# %% [markdown]
# **Question:** After reviewing the profit information across each date from the different time periods, can you identify any patterns or trends?
#
# **Answer:** The trend you notice even prior to reviewing the profit information, is on the Bitstamp and Coinbase overlay.  You notice in January you have differences in the overlay that are signifigant.  As you move further down the chart the overlay becomes less indicating the close prices got similiar on both market places over the time period.

# %%
bitstamp['Close'].plot(legend=True, figsize=(20, 15), title="Bitstamp v Coinbase", color="blue", label="Bitstamp")
coinbase['Close'].plot(legend=True, figsize=(20, 15), color="red", label="Coinbase")
# Out:
# <AxesSubplot:title={'center':'Bitstamp v Coinbase'}, xlabel='Timestamp'>

# %% [markdown]
# The table above is the data for the first quarter of 2018.  You can see in January that the overlay deviates several times in January and has less deviations in February and March.  This indicates the close prices became similiar over time during this time frame.

# %% [markdown]
# After that you can see when data is pulled by a specific date in each month the overlay plots are closer together with January having the largest deviations in close price.

# %%
bitstamp['Close'].loc['2018-01-29'].plot(
    legend=True, figsize=(15, 10), title="Bitstamp v Coinbase January 29th, 2018", color="blue", label="Bitstamp")
coinbase['Close'].loc['2018-01-29'].plot(
    legend=True, figsize=(15, 10), color="red", label="Coinbase")

bitstamp['Close'].loc['2018-02-02'].plot(
    legend=True, figsize=(15, 10), title="Bitstamp v Coinbase Groundhog Day 2018", color="blue", label="Bitstamp")
coinbase['Close'].loc['2018-02-02'].plot(
    legend=True, figsize=(15, 10), color="red", label="Coinbase")

bitstamp['Close'].loc['2018-03-02'].plot(
    legend=True, figsize=(15, 10), title="Bitstamp v Coinbase January 29th, February 2nd, and March 2nd, 2018", color="blue", label="Bitstamp")
coinbase['Close'].loc['2018-03-02'].plot(
    legend=True, figsize=(15, 10), color="red", label="Coinbase")
# Out:
# <AxesSubplot:title={'center':'Bitstamp v Coinbase January 29th, February 2nd, and March 2nd, 2018'}, xlabel='Timestamp'>

# %% [markdown]
# Plotting the three individual days you can clearly see several deviations in close price  for the date in January (01-29-2018), then you see deviations in close price in February (February 2nd, 2018) mainly at the highs and lows druing the day and finally for the March date you have some deviations but not as pronounced as the January and February date.
#
#
# Next looking at the data to create the arbitrage profits we notice the counts on each day greater than zero, along with number of transactions above one percent to cover fees to make trades.
#
#
# ![image.png](attachment:7a49c0a8-0464-4b16-9560-858f3e9b0c2a.png)
#
#
# You can see some trends with this data looking at the number of changes in close prices with a difference of zero they decrease as we move through time in the data.  Next we have the close price count greater than 1 percent.  It drastically reduces from January to March this also demonstrates that the close price can have differences but the prices are closer to each other.  The percenatage reinforces this trend by going from above half in January to zero in March.
#
# The March have zero transactions are due to a couple items:
# 1.  The accuracy of the close prices over time contributed to the zero transactions greater than one percent.
# 2.  The price from February to March increased causing a larger variance than February to achieve the one percent difference.

# %% [markdown]
# Next we will look at the cumulative profits from each day.

# %%
cumulative_profit_early.plot(figsize=(10, 7), title="Cumulative January 29th, 2018 Profits")
cumulative_profit_middle.plot(figsize=(10, 7), title="Cumulative February 2nd (Groundhog Day), 2018 Profits")
cumulative_profit_late.plot(figsize=(10, 7), title="Cumulative January 29th, February 2nd, and March 2nd, 2018 Profits")
# Out:
# <AxesSubplot:title={'center':'Cumulative January 29th, February 2nd, and March 2nd, 2018 Profits'}, xlabel='Timestamp'>

# %% [markdown]
# The profit potential for arbitrage was incredible on January 29th, 2018 and the cumulative profit potential was 148,647.30.  Compared to February 2nd, 2018 with a potential cumulative profit of $3,135.73 and then with March 2nd, 2018 with zero potential arbitrage profit.
# Based on the data the potential for arbitrage was available in January between closing prices in Bitstamp and Coinbase marketplaces.  As time progressed the opportunity was reduced and finally disappeared due to similiar close prices that developed as time progressed.

# %% [markdown]
# Arbitrage opportunites are few and far between and do not last long once discovered.  This data shows that the potential for profit was available in January but as the two marketplaces started to have similiar close data the opportunity reduced and then disappeared.
